# %%
# Write an SQL query to fetch “FIRST_NAME” from Worker table using the alias name as <WORKER_NAME>.
select firstname as workername from workertable;

# %% [markdown]
# ![Screenshot from 2022-02-10 11-11-35.png](data:image/png;base64,...)

# %%
#  Write an SQL query to fetch unique values of DEPARTMENT from Worker table.

select distinct department from workertable;

# %% [markdown]
# ![Screenshot from 2022-02-10 11-20-42.png](data:image/png;base64,...)

# %%
# Write an SQL query to show the last 5 record from a table.
select * from workertable where id > (select count(*) from workertable)-5

# %% [markdown]
# ![Screenshot from 2022-02-10 11-37-18.png](data:image/png;base64,...)
